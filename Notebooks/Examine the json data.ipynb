# %%
import json
import numpy as np

# %%
ls ../data/serving/X
# Out:
# 0000000.json  0002000.json  0004000.json  0006000.json  0008000.json
# 0000000.npy   0002000.npy   0004000.npy   0006000.npy   0008000.npy
# 0000001.json  0002001.json  0004001.json  0006001.json  0008001.json
# 0000001.npy   0002001.npy   0004001.npy   0006001.npy   0008001.npy
# 0000002.json  0002002.json  0004002.json  0006002.json  0008002.json
# 0000002.npy   0002002.npy   0004002.npy   0006002.npy   0008002.npy
# 0000003.json  0002003.json  0004003.json  0006003.json  0008003.json
# 0000003.npy   0002003.npy   0004003.npy   0006003.npy   0008003.npy
# 0000004.json  0002004.json  0004004.json  0006004.json  0008004.json
# 0000004.npy   0002004.npy   0004004.npy   0006004.npy   0008004.npy
# 0000005.json  0002005.json  0004005.json  0006005.json  0008005.json
# 0000005.npy   0002005.npy   0004005.npy   0006005.npy   0008005.npy
# 0000006.json  0002006.json  0004006.json  0006006.json  0008006.json
# 0000006.npy   0002006.npy   0004006.npy   0006006.npy   0008006.npy
# ...

# %%
data = json.load(open('../data/serving/X/0000000.json'))

# %%
len(data)
# Out:
# 28

# %%
data1 = np.array(data)

# %%
data1.shape
# Out:
# (28, 28, 1)
